# %% [markdown]
# <a href="https://colab.research.google.com/github/team0243/practic/blob/main/map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install leafmap

# %%
import leafmap

# %%
m = leafmap.Map(google_map="HYBRID")
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
m = leafmap.Map(google_map="TERRAIN")
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
import os
import xyzservices.providers as xyz

# %%
basemap = xyz.HEREv3.basicMap
basemap
# Out:
# {'url': 'https://{s}.{base}.maps.ls.hereapi.com/maptile/2.1/{type}/{mapID}/{variant}/{z}/{x}/{y}/{size}/{format}?apiKey={apiKey}&lg={language}',
#  'html_attribution': 'Map &copy; 1987-2023 <a href="http://developer.here.com">HERE</a>',
#  'attribution': 'Map (C) 1987-2023 HERE',
#  'subdomains': '1234',
#  'mapID': 'newest',
#  'apiKey': '<insert your apiKey here>',
#  'base': 'base',
#  'variant': 'normal.day',
#  'max_zoom': 20,
#  'type': 'basetile',
#  'language': 'eng',
#  'format': 'png8',
#  'size': '256',
#  'name': 'HEREv3.basicMap'}

# %%
basemap['apiKey'] = os.environ["HEREMAPS_API_KEY"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-9002d75c0fa5> in <module>
# ----> 1 basemap['apiKey'] = os.environ["HEREMAPS_API_KEY"]
#
# /usr/lib/python3.8/os.py in __getitem__(self, key)
#     673         except KeyError:
#     674             # raise KeyError with the original key value
# --> 675             raise KeyError(key) from None
#     676         return self.decodevalue(value)
#     677
#
# KeyError: 'HEREMAPS_API_KEY'

# %%
m = leafmap.Map()
m.add_basemap(basemap)
m
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/leafmap/leafmap.py in add_basemap(self, basemap, show, **kwargs)
#     288                 name = basemap.name
# --> 289                 url = basemap.build_url()
#     290                 attribution = basemap.attribution
#
# /usr/local/lib/python3.8/dist-packages/xyzservices/lib.py in build_url(self, x, y, z, scale_factor, fill_subdomain, **kwargs)
#     449         if provider.requires_token():
# --> 450             raise ValueError(
#     451                 "Token is required for this provider, but not provided. "
#
# ValueError: Token is required for this provider, but not provided. You can either update TileProvider or pass respective keywords to build_url().
#
# During handling of the above exception, another exception occurred:
#
# ...
